# %% [markdown]
# ####

# %% [markdown]
# # Month 1 Python
#
# ### Covered - TUPLES, SETS, DICTIONARIES

# %% [markdown]
# ## Tuples :
# - Tuples are similar to lists, ordered but cannot be changed once they are created (IMMUTABLE)
# - Used to store multiple balues in a single variable
# - Immutable meaning unchangeable
# - Tuples are declared on ( ) brackets

# %%
point = (3, 5)

# %% [markdown]
# Why use a tuple?
#
# When data should stay fixed.
#
# When you want to protect values from accidental changes.
#
# Example: coordinates, dates, or fixed settings.

# %%
days = ("Mon", "Tue", "Wed")

# %% [markdown]
# ##### Think of a tuple as a “frozen list”.
# - A frozen list = a list that cannot be changed after it’s created

# %%
## len function
len(days)
# Out:
# 3

# %% [markdown]
# ### You need to understand the difference between lenngth function and indexing
# - position of values always starts from 0, but length starts from 1

# %%
## creating tuple with one value
thistuple = ("apple",)
print(type(thistuple))
# Out:
# <class 'tuple'>

# %%
### Tuple items can be of any data type:

# %%
tuple1 = ("apple", "banana", "cherry")
tuple2 = (1, 5, 7, 9, 3)
tuple3 = (True, False, False)

# %%
tuple4= ("apple",4,True)

# %% [markdown]
# #### Accessing tuples

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple[1])
# Out:
# banana

# %%
## negative indexing
thistuple = ("apple", "banana", "cherry")
print(thistuple[-1])
# Out:
# cherry

# %%
## range of indexes
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[2:5])
# Out:
# ('cherry', 'orange', 'kiwi')

# %% [markdown]
# #### Check if Item Exists

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
if 'apple' in thistuple:
    print("yes")
# Out:
# yes

# %% [markdown]
# #### Updating tuples
# - Tuples are unchangeable, meaning that you cannot change, add, or remove items once the tuple is created.
# - But there is a workaround. You can convert the tuple into a list, change the list, and convert the list back into a tuple.

# %%
x = ("apple", "banana", "cherry")
y = list(x)
y[1] ='mango'
x=tuple(y)
print(x)
# Out:
# ('apple', 'mango', 'cherry')

# %% [markdown]
# ##### Add Items

# %%
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)
y.append("orange")
thistuple = tuple(y)
thistuple
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
### adding tuple to a tuple
thistuple = ("apple", "banana", "cherry")
y = ("orange",)
thistuple += y

print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'orange')

# %%
### remove items
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)
y.remove("apple")
thistuple = tuple(y)
thistuple
# Out:
# ('banana', 'cherry')

# %%
### delete
thistuple = ("apple", "banana", "cherry")
del thistuple
print(thistuple) #this will raise an error because the tuple no longer exists
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 4
#       2 thistuple = ("apple", "banana", "cherry")
#       3 del thistuple
# ----> 4 print(thistuple) #this will raise an error because the tuple no longer exists
#
# NameError: name 'thistuple' is not defined

# %% [markdown]
# #### Unpack tuples

# %%
fruits = ("apple", "banana", "cherry")

# %%
a,b,c =("apple", "banana", "cherry")
a
# Out:
# 'apple'

# %%
b
# Out:
# 'banana'

# %%
c
# Out:
# 'cherry'

# %%
fruits = ("apple", "banana", "cherry")

(green, yellow, red) = fruits

print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# #### Using * Asterisk
# - If the number of variables is less than the number of values, you can add an * to the variable name and the values will be assigned to the variable as a list:

# %%
fruits = ("apple", "banana", "cherry", "strawberry", "raspberry")

(green, yellow, *red) = fruits

print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# ['cherry', 'strawberry', 'raspberry']

# %%
fruits = ("apple", "mango", "papaya", "pineapple", "cherry")

(green, *tropic, red) = fruits

print(green)
print(tropic)
print(red)
# Out:
# apple
# ['mango', 'papaya', 'pineapple']
# cherry

# %% [markdown]
# ### Loop Tuples

# %%
fruits = ("apple", "mango", "papaya", "pineapple", "cherry")
for x in fruits:
    print(x)
# Out:
# apple
# mango
# papaya
# pineapple
# cherry

# %%
thistuple = ("apple", "banana", "cherry")
for i in range(len(thistuple)):
  print(thistuple[i])
# Out:
# apple
# banana
# cherry

# %%
thistuple = ("apple", "banana", "cherry")
i=0
while i <len(thistuple):
    print(thistuple[i])
    i=i+1
# Out:
# apple
# banana
# cherry

# %% [markdown]
# ### Join tuples

# %%
tuple1 = ("a", "b" , "c")
tuple2 = (1, 2, 3)

tuple3 = tuple1 + tuple2
print(tuple3)
# Out:
# ('a', 'b', 'c', 1, 2, 3)

# %%
### Multiply tuples
fruits = ("apple", "banana", "cherry")
mytuple = fruits * 2

print(mytuple)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'banana', 'cherry')

# %% [markdown]
# #### Tuple methods:
# | Method  | Description                                                                 |
# |---------|-----------------------------------------------------------------------------|
# | count() | Returns the number of times a specified value occurs in a tuple             |
# | index() | Searches the tuple for a specified value and returns its first position     |

# %% [markdown]
# ## SETS
# - Sets are used to store multiple items in a single variable.
# - A set is a collection which is unordered, unchangeable, and unindexed.
# - No duplicate values

# %%
## creating set
thisset = {"apple", "banana", "cherry"}
print(thisset)
# Out:
# {'cherry', 'banana', 'apple'}

# %%
## len of set
thisset = {"apple", "banana", "cherry"}

print(len(thisset))
# Out:
# 3

# %%
## set items can be of any data type:

set1 = {"apple", "banana", "cherry"}
set2 = {1, 5, 7, 9, 3}
set3 = {True, False, False}

# %%
set1 = {"abc", 34, True, 40, "male"}

# %%
set1
# Out:
# {34, 40, True, 'abc', 'male'}

# %% [markdown]
# #### Access set items

# %%
thisset = {"apple", "banana", "cherry"}
for i in thisset:
    print(i)
# Out:
# cherry
# banana
# apple

# %%
thisset = {"apple", "banana", "cherry"}

print("banana" in thisset)
# Out:
# True

# %%
thisset = {"apple", "banana", "cherry"}

print("banana" not in thisset)
# Out:
# False

# %% [markdown]
# #### Once a set is created, you cannot change its items, but you can add new items.

# %% [markdown]
# #### Add items

# %%
thisset = {"apple", "banana", "cherry"}

thisset.add("orange")

print(thisset)
# Out:
# {'orange', 'cherry', 'banana', 'apple'}

# %%
thisset = {"apple", "banana", "cherry"}
tropical = {"pineapple", "mango", "papaya"}

thisset.update(tropical)

print(thisset)
# Out:
# {'pineapple', 'mango', 'banana', 'papaya', 'cherry', 'apple'}

# %%
thisset = {"apple", "banana", "cherry"}
mylist = ["kiwi", "orange"]

thisset.update(mylist)

print(thisset)
# Out:
# {'banana', 'cherry', 'apple', 'orange', 'kiwi'}

# %% [markdown]
# #### Remove items

# %%
thisset = {"apple", "banana", "cherry"}

thisset.remove("banana")

print(thisset)
# Out:
# {'cherry', 'apple'}

# %%
thisset = {"apple", "banana", "cherry"}

thisset.discard("banana")

print(thisset)
# Out:
# {'cherry', 'apple'}

# %%
thisset = {"apple", "banana", "cherry"}

x = thisset.pop()

print(x)

print(thisset)
# Out:
# cherry
# {'banana', 'apple'}

# %%
##clearing set
thisset = {"apple", "banana", "cherry"}

thisset.clear()

print(thisset)
# Out:
# set()

# %%
### deleting set

thisset = {"apple", "banana", "cherry"}

del thisset

print(thisset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 7
#       3 thisset = {"apple", "banana", "cherry"}
#       5 del thisset
# ----> 7 print(thisset)
#
# NameError: name 'thisset' is not defined

# %% [markdown]
# ### Loop SETS

# %%
thisset = {"apple", "banana", "cherry"}

for x in thisset:
  print(x)
# Out:
# cherry
# banana
# apple

# %% [markdown]
# #### Join SETS
#
# - There are several ways to join two or more sets in Python.
# - The union() and update() methods joins all items from both sets.
# - The intersection() method keeps ONLY the duplicates.
# - The difference() method keeps the items from the first set that are not in the other set(s).
# - The symmetric_difference() method keeps all items EXCEPT the duplicates.

# %%
### UNION - The union() method returns a new set with all items from both sets.

set1 = {"a", "b", "c"}
set2 = {1, 2, 3}

set3 = set1.union(set2)
print(set3)
# Out:
# {1, 2, 3, 'b', 'a', 'c'}

# %%
## You can use the | operator instead of the union() method, and you will get the same result.
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}

set3 = set1 | set2
print(set3)
# Out:
# {1, 2, 3, 'b', 'a', 'c'}

# %%
## JOINING MULTIPLE SETS

set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = {"John", "Elena"}
set4 = {"apple", "bananas", "cherry"}

myset = set1.union(set2, set3, set4)
print(myset)
# Out:
# {1, 2, 3, 'b', 'Elena', 'cherry', 'c', 'bananas', 'apple', 'John', 'a'}

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = {"John", "Elena"}
set4 = {"apple", "bananas", "cherry"}

myset = set1 | set2 | set3 |set4
print(myset)
# Out:
# {1, 2, 3, 'b', 'Elena', 'cherry', 'c', 'bananas', 'apple', 'John', 'a'}

# %%
## Join a Set and a Tuple
x = {"a", "b", "c"}
y = (1, 2, 3)

z = x.union(y)
print(z)
# Out:
# {1, 2, 3, 'b', 'c', 'a'}

# %% [markdown]
# #### Update
# The update() method inserts all items from one set into another.
#
# The update() changes the original set, and does not return a new set.

# %%
set1 = {"a", "b" , "c"}
set2 = {1, 2, 3}

set1.update(set2)
print(set1)
# Out:
# {1, 2, 3, 'b', 'a', 'c'}

# %% [markdown]
# #### INTERSECTION
# - Keep ONLY the duplicates
# - The intersection() method will return a new set, that only contains the items that are present in both sets.

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.intersection(set2)
print(set3)
# Out:
# {'apple'}

# %% [markdown]
# ##### You can use the & operator instead of the intersection() method, and you will get the same result.

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1 & set2
print(set3)
# Out:
# {'apple'}

# %% [markdown]
# #### The intersection_update() method will also keep ONLY the duplicates, but it will change the original set instead of returning a new set.

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.intersection_update(set2)

print(set1)
# Out:
# {'apple'}

# %% [markdown]
# #### The difference() method will return a new set that will contain only the items from the first set that are not present in the other set.

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.difference(set2)

print(set3)
# Out:
# {'cherry', 'banana'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1 - set2
print(set3)
# Out:
# {'cherry', 'banana'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.difference_update(set2)

print(set1)
# Out:
# {'cherry', 'banana'}

# %% [markdown]
# #### Symmetric Differences
# The symmetric_difference() method will keep only the elements that are NOT present in both sets.

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1.symmetric_difference(set2)

print(set3)
# Out:
# {'banana', 'cherry', 'microsoft', 'google'}

# %%
### You can use the ^ operator instead of the symmetric_difference() method, and you will get the same result.

set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1 ^ set2
print(set3)
# Out:
# {'banana', 'cherry', 'microsoft', 'google'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set1.symmetric_difference_update(set2)

print(set1)
# Out:
# {'banana', 'cherry', 'microsoft', 'google'}

# %% [markdown]
# #### Frozen set
# frozenset is an immutable version of a set.
#
# Like sets, it contains unique, unordered, unchangeable elements.
#
# Unlike sets, elements cannot be added or removed from a frozenset.

# %%
## creating a frozenset
x = frozenset({"apple", "banana", "cherry"})
print(x)
print(type(x))
# Out:
# frozenset({'cherry', 'banana', 'apple'})
# <class 'frozenset'>

# %% [markdown]
# ## Frozenset Methods:
#
# | Method                  | Shortcut   | Description                                                     |
# |-------------------------|------------|-----------------------------------------------------------------|
# | copy()                  |            | Returns a shallow copy                                          |
# | difference()            | -          | Returns a new frozenset with the difference                     |
# | intersection()          | &          | Returns a new frozenset with the intersection                   |
# | isdisjoint()            |            | Returns whether two frozensets have no common elements          |
# | issubset()              | <= / <     | Returns True if this is a (proper) subset of another            |
# | issuperset()            | >= / >     | Returns True if this is a (proper) superset of another          |
# | symmetric_difference()  | ^          | Returns a new frozenset with symmetric differences              |
# | union()                 | |          | Returns a new frozenset containing the union                    |

# %% [markdown]
# ## SET Methods:
#
# | Method                         | Shortcut | Description                                                                 |
# |--------------------------------|----------|-----------------------------------------------------------------------------|
# | add()                          |          | Adds an element to the set                                                  |
# | clear()                        |          | Removes all elements from the set                                           |
# | copy()                         |          | Returns a copy of the set                                                   |
# | difference()                   | -        | Returns a set with elements in this set but not in others                   |
# | difference_update()            | -=       | Removes elements found in another set from this set                         |
# | discard()                      |          | Removes the specified element (no error if not found)                       |
# | intersection()                 | &        | Returns a set with common elements between sets                             |
# | intersection_update()          | &=       | Keeps only elements present in both sets                                    |
# | isdisjoint()                   |          | Returns True if two sets have no elements in common                         |
# | issubset()                     | <= / <   | Returns True if all elements are in another (or strictly smaller) set       |
# | issuperset()                   | >= / >   | Returns True if this set contains another (or strictly larger) set          |
# | pop()                          |          | Removes and returns a random element                                        |
# | remove()                       |          | Removes the specified element (error if not found)                          |
# | symmetric_difference()         | ^        | Returns elements present in either set but not both                         |
# | symmetric_difference_update()  | ^=       | Updates set with symmetric differences                                      |
# | union()                        | |        | Returns a set containing all elements from both sets                        |
# | update()                       | |=       | Updates the set with elements from another set                              |

# %% [markdown]
# ## DICTIONARIES
# - Dictionaries are used to store data values in key:value pairs
# - Dictionary is a collection of ordered, changeable and do not allow duplicates.
# - Dictionaries are declared in { } brackets

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
print(thisdict['brand'])
# Out:
# Ford

# %%
## duplicates check - not allowed

thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "year": 2020
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}

# %%
len(thisdict)
# Out:
# 3

# %%
## can store any data type 

thisdict = {
  "brand": "Ford",
  "electric": False,
  "year": 1964,
  "colors": ["red", "white", "blue"]
}

# %%
thisdict = dict(name = "John", age = 36, country = "Norway")
print(thisdict)
# Out:
# {'name': 'John', 'age': 36, 'country': 'Norway'}

# %% [markdown]
# #### Accessing items:

# %%
thisdict
# Out:
# {'name': 'John', 'age': 36, 'country': 'Norway'}

# %%
x = thisdict['name']
x
# Out:
# 'John'

# %%
x= thisdict.get('age')
x
# Out:
# 36

# %%
thisdict.keys()
# Out:
# dict_keys(['name', 'age', 'country'])

# %%
thisdict.values()
# Out:
# dict_values(['John', 36, 'Norway'])

# %%
thisdict
# Out:
# {'name': 'John', 'age': 36, 'country': 'Norway'}

# %%
thisdict['student'] = 'yes'
thisdict
# Out:
# {'name': 'John', 'age': 36, 'country': 'Norway', 'student': 'yes'}

# %%
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

x = car.values()

print(x) #before the change

car["year"] = 2020

print(x) #after the change
# Out:
# dict_values(['Ford', 'Mustang', 1964])
# dict_values(['Ford', 'Mustang', 2020])

# %%
x = thisdict.items()
x
# Out:
# dict_items([('name', 'John'), ('age', 36), ('country', 'Norway'), ('student', 'yes')])

# %% [markdown]
# #### check if key exists:

# %%
if 'age' in thisdict:
    print('yes')
else:
    print('sorry, not in list')
# Out:
# yes

# %% [markdown]
# #### Changing DICT Items:

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict["year"] = 2018

# %% [markdown]
# #### UPDATE

# %%
thisdict.update({'year' : 2020})

# %%
thisdict
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}

# %% [markdown]
# #### ADD ITEMS

# %%
thisdict['color' ]= 'pink'
thisdict
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020, 'color': 'pink'}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.update({"color": "red"})

# %%
thisdict
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'red'}

# %% [markdown]
# #### REMOVE

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.pop("model")
print(thisdict)
# Out:
# {'brand': 'Ford', 'year': 1964}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.popitem()
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang'}

# %% [markdown]
# - The pop() method removes the item with the specified key name:
# - The popitem() method removes the last inserted item

# %% [markdown]
# #### Delete dict

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
del thisdict["model"]
print(thisdict)
# Out:
# {'brand': 'Ford', 'year': 1964}

# %% [markdown]
# ##### CLEAR DICT

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.clear()
print(thisdict)
# Out:
# {}

# %% [markdown]
# ### LOOPING DICT

# %%
## TO GET KEYS

thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
for x in thisdict:
    print(x)
# Out:
# brand
# model
# year

# %%
## TO GET VALUES

for x in thisdict:
  print(thisdict[x])
# Out:
# Ford
# Mustang
# 1964

# %%
for x in thisdict.values():
  print(x)
# Out:
# Ford
# Mustang
# 1964

# %%
for x in thisdict.keys():
    print(x)
# Out:
# brand
# model
# year

# %%
for x,y in thisdict.items():
    print(x, y)
# Out:
# brand Ford
# model Mustang
# year 1964

# %% [markdown]
# #### COPY DICT#
# - You cannot copy a dictionary simply by typing dict2 = dict1, because: dict2 will only be a reference to dict1, and changes made in dict1 will automatically also be made in dict2.
# - There are ways to make a copy, one way is to use the built-in Dictionary method copy().

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
mydict = thisdict.copy()
print(mydict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
mydict = dict(thisdict)
print(mydict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %% [markdown]
# #### NESTED DICT
# - A dictionary can contain dictionaries, this is called nested dictionaries.

# %%
myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}

# %%
myfamily
# Out:
# {'child1': {'name': 'Emil', 'year': 2004},
#  'child2': {'name': 'Tobias', 'year': 2007},
#  'child3': {'name': 'Linus', 'year': 2011}}

# %%
child1 = {
  "name" : "Emil",
  "year" : 2004
}
child2 = {
  "name" : "Tobias",
  "year" : 2007
}
child3 = {
  "name" : "Linus",
  "year" : 2011
}

myfamily = {
  "child1" : child1,
  "child2" : child2,
  "child3" : child3
}

# %%
myfamily
# Out:
# {'child1': {'name': 'Emil', 'year': 2004},
#  'child2': {'name': 'Tobias', 'year': 2007},
#  'child3': {'name': 'Linus', 'year': 2011}}

# %% [markdown]
# #### Access items in NESTED DICT

# %%
print(myfamily['child1']['name'])
# Out:
# Emil

# %% [markdown]
# #### LOOP THROUGH NESTED DICT

# %%
for x, obj in myfamily.items():
  print(x)

  for y in obj:
    print(y + ':', obj[y])
# Out:
# child1
# name: Emil
# year: 2004
# child2
# name: Tobias
# year: 2007
# child3
# name: Linus
# year: 2011

# %% [markdown]
# ### Dictionary Methods:
# | Method         | Description                                                                 |
# |----------------|-----------------------------------------------------------------------------|
# | clear()        | Removes all elements from the dictionary                                    |
# | copy()         | Returns a copy of the dictionary                                            |
# | fromkeys()     | Creates a dictionary with specified keys and a common value                 |
# | get()          | Returns the value of a specified key (no error if key is missing)           |
# | items()        | Returns key-value pairs as tuples                                           |
# | keys()         | Returns all the keys in the dictionary                                      |
# | pop()          | Removes the element with the specified key                                  |
# | popitem()      | Removes the last inserted key-value pair                                    |
# | setdefault()   | Returns value of key; if not present, inserts key with given value          |
# | update()       | Updates dictionary with new key-value pairs                                 |
# | values()       | Returns all the values in the dictionary                                    |
