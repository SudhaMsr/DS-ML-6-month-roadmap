# %% [markdown]
# ###

# %% [markdown]
# # Month 1 Python
#
# ### Covered - Modular code

# %% [markdown]
# Modular code means:
#
# Breaking big code into smaller organized pieces.
#
# Instead of writing everything in ONE huge block.

# %%
def clean_data():
    pass

def analyze_data():
    pass

def save_results():
    pass

##instead of writing a huge block of code

# %%
def add(a, b):
    return a + b

print(add(2, 3))
# Out:
# 5
